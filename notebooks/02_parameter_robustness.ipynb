# %% [markdown]
# # 02 — Parameter Robustness
#
# Sweep key parameters (state_lookback, bull/bear threshold, training_window)
# and measure how stable the signal's predictive power is across the space.
#
# **Status:** Not yet implemented — populate after notebook 01 establishes
# that the baseline signal has predictive value.

# %%
# TODO: parameter grid sweep
# Parameters to vary:
#   state_lookback: [10, 15, 20, 30]
#   bull/bear threshold: [3, 5, 7, 10]
#   training_window: [250, 500, 750]
#
# For each combination, recompute the dataset and record:
#   - Pearson/Spearman correlation (signal vs 5d return)
#   - Quantile spread (Q4 mean return - Q0 mean return)
print("Parameter robustness notebook — to be implemented.")
